# %%
from wwo_hist import retrieve_hist_data

# %%
frequency=24
start_date = '02-JAN-2010'
end_date = '13-JUL-2022'
api_key = 'e8cd88f8a7da49659f904854220612' #Individual user API can be optained from https://www.worldweatheronline.com/weather-api/api/ 
location_list = ['somerset']
        
hist_weather_data = retrieve_hist_data(api_key,location_list,start_date,end_date,frequency,location_label = False,export_csv = True,store_df = True)
# Out:
# Retrieving weather data for somerset
# C:\Users\vivek\miniconda3\envs\tensorflow\lib\site-packages\wwo_hist\__init__.py:69: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   list_mon_begin = pd.date_range(start_date, end_date, freq='MS', closed='right')
# C:\Users\vivek\miniconda3\envs\tensorflow\lib\site-packages\wwo_hist\__init__.py:74: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   list_mon_end = pd.date_range(start_date, end_date, freq='M', closed='left')
# Currently retrieving data for somerset: from 2010-01-02 to 2010-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.300309
# Currently retrieving data for somerset: from 2010-02-01 to 2010-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:03.364795
# Currently retrieving data for somerset: from 2010-03-01 to 2010-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.496588
# Currently retrieving data for somerset: from 2010-04-01 to 2010-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:05.677745
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/vivek/Downloads/Historical-Weather-Data-Scraper-master/somerset.csv")

# %%
df.head()
# Out:
#     date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 0  2010-01-02        29        16           0.0     14.5        7
# 1  2010-01-03        20        14           0.0     12.4        4
# 2  2010-01-04        26        14           0.0     14.5        6
# 3  2010-01-05        35        16           0.0     14.5        7
# 4  2010-01-06        25        16           0.0     14.5        6
#
#    moon_illumination  moonrise   moonset   sunrise  ... WindGustKmph  \
# 0                 85  09:31 PM  07:18 AM  05:38 AM  ...           23
# 1                 77  10:08 PM  08:32 AM  05:38 AM  ...           25
# 2                 70  10:41 PM  09:44 AM  05:39 AM  ...           34
# 3                 63  11:13 PM  10:52 AM  05:40 AM  ...           22
# 4                 56  11:44 PM  11:59 AM  05:41 AM  ...           19
#
#    cloudcover  humidity  precipMM  pressure  tempC  visibility  winddirDegree  \
# ...

# %%
df = df.rename(columns={'date_time': 'Date'})

# %%
df.head()
# Out:
#          Date  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 0  2010-01-02        29        16           0.0     14.5        7
# 1  2010-01-03        20        14           0.0     12.4        4
# 2  2010-01-04        26        14           0.0     14.5        6
# 3  2010-01-05        35        16           0.0     14.5        7
# 4  2010-01-06        25        16           0.0     14.5        6
#
#    moon_illumination  moonrise   moonset   sunrise  ... WindGustKmph  \
# 0                 85  09:31 PM  07:18 AM  05:38 AM  ...           23
# 1                 77  10:08 PM  08:32 AM  05:38 AM  ...           25
# 2                 70  10:41 PM  09:44 AM  05:39 AM  ...           34
# 3                 63  11:13 PM  10:52 AM  05:40 AM  ...           22
# 4                 56  11:44 PM  11:59 AM  05:41 AM  ...           19
#
#    cloudcover  humidity  precipMM  pressure  tempC  visibility  winddirDegree  \
# ...

# %%
df['Date'] =  pd.to_datetime(df['Date'])

# %%
df.head()
# Out:
#         Date  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 0 2010-01-02        29        16           0.0     14.5        7
# 1 2010-01-03        20        14           0.0     12.4        4
# 2 2010-01-04        26        14           0.0     14.5        6
# 3 2010-01-05        35        16           0.0     14.5        7
# 4 2010-01-06        25        16           0.0     14.5        6
#
#    moon_illumination  moonrise   moonset   sunrise  ... WindGustKmph  \
# 0                 85  09:31 PM  07:18 AM  05:38 AM  ...           23
# 1                 77  10:08 PM  08:32 AM  05:38 AM  ...           25
# 2                 70  10:41 PM  09:44 AM  05:39 AM  ...           34
# 3                 63  11:13 PM  10:52 AM  05:40 AM  ...           22
# 4                 56  11:44 PM  11:59 AM  05:41 AM  ...           19
#
#    cloudcover  humidity  precipMM  pressure  tempC  visibility  winddirDegree  \
# ...

# %%
mask = (df['Date'] > '2012-12-1') & (df['Date'] <= '2014-8-1')

# %%
mask1 = (df['Date'] > '2016-12-1') & (df['Date'] <= '2018-8-1')

# %%
df1 = df.loc[mask]

# %%
df2 = df.loc[mask1]

# %%
df1.head()
# Out:
#            Date  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 1065 2012-12-02        25        14           0.0     14.2        6
# 1066 2012-12-03        22        13           0.0     14.2        4
# 1067 2012-12-04        21        12           0.0     14.2        5
# 1068 2012-12-05        24        12           0.0     14.2        6
# 1069 2012-12-06        26        15           0.0     14.2        6
#
#       moon_illumination     moonrise   moonset   sunrise  ... WindGustKmph  \
# 1065                 71     10:36 PM  08:33 AM  05:26 AM  ...           28
# 1066                 64     11:12 PM  09:28 AM  05:26 AM  ...           20
# 1067                 56     11:46 PM  10:25 AM  05:26 AM  ...           27
# 1068                 49  No moonrise  11:23 AM  05:26 AM  ...           33
# 1069                 42     12:19 AM  12:21 PM  05:26 AM  ...           20
#
#       cloudcover  humidity  precipMM  pressure  tempC  visibility  \
# ...

# %%
df1.shape
# Out:
# (608, 25)

# %%
df2.head()
# Out:
#            Date  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 2526 2016-12-02        27        15           0.0     14.2        6
# 2527 2016-12-03        26        11           0.0     14.2        6
# 2528 2016-12-04        23        10           0.0     14.2        5
# 2529 2016-12-05        30        11           0.0     13.4        5
# 2530 2016-12-06        27        13           0.0     14.2        6
#
#       moon_illumination  moonrise     moonset   sunrise  ... WindGustKmph  \
# 2526                 16  07:51 AM    10:03 PM  05:26 AM  ...           22
# 2527                 23  08:42 AM    10:48 PM  05:26 AM  ...           17
# 2528                 31  09:37 AM    11:30 PM  05:26 AM  ...           20
# 2529                 38  10:34 AM  No moonset  05:26 AM  ...           21
# 2530                 45  11:33 AM    12:10 AM  05:26 AM  ...           15
#
#       cloudcover  humidity  precipMM  pressure  tempC  visibility  \
# ...

# %%
df2.shape
# Out:
# (608, 25)

# %%
import matplotlib.pyplot as plt

# %%
df.plot(subplots=True, layout=(40,50))
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, ...,
#         <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, ...,
#         <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, ...,
#         <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        ...,
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, ...,
#         <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, ...,
#         <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, ...,
#         <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
df.columns
# Out:
# Index(['Date', 'maxtempC', 'mintempC', 'totalSnow_cm', 'sunHour', 'uvIndex',
#        'moon_illumination', 'moonrise', 'moonset', 'sunrise', 'sunset',
#        'DewPointC', 'FeelsLikeC', 'HeatIndexC', 'WindChillC', 'WindGustKmph',
#        'cloudcover', 'humidity', 'precipMM', 'pressure', 'tempC', 'visibility',
#        'winddirDegree', 'windspeedKmph', 'location'],
#       dtype='object')

# %%
df1.plot(x="Date", y=['maxtempC' , 'mintempC','totalSnow_cm', 'sunHour', 'uvIndex',
       'moon_illumination', 'moonrise', 'moonset', 'sunrise', 'sunset',
       'DewPointC', 'FeelsLikeC', 'HeatIndexC', 'WindChillC', 'WindGustKmph',
       'cloudcover', 'humidity', 'precipMM', 'pressure', 'tempC', 'visibility',
       'winddirDegree', 'windspeedKmph', 'location'],figsize=(30,30))
plt.show()

# %%
df1.plot(x="Date", y=['maxtempC' , 'mintempC'],figsize=(30,30))
plt.show()

# %%
df.plot(x="Date", y=['totalSnow_cm'],figsize=(50,50))
plt.show()

# %%
df.corr()
# Out:
#                    maxtempC  mintempC  totalSnow_cm   sunHour   uvIndex  \
# maxtempC           1.000000  0.765007           NaN  0.606385  0.904958
# mintempC           0.765007  1.000000           NaN  0.441827  0.705690
# totalSnow_cm            NaN       NaN           NaN       NaN       NaN
# sunHour            0.606385  0.441827           NaN  1.000000  0.645145
# uvIndex            0.904958  0.705690           NaN  0.645145  1.000000
# moon_illumination  0.012138  0.014714           NaN -0.006358  0.006147
# DewPointC          0.679196  0.852308           NaN  0.447445  0.624418
# FeelsLikeC         0.930794  0.920960           NaN  0.579370  0.860531
# HeatIndexC         0.929475  0.924348           NaN  0.573242  0.858777
# WindChillC         0.929399  0.922500           NaN  0.581541  0.860477
# WindGustKmph      -0.172483 -0.077945           NaN -0.164081 -0.189805
# cloudcover        -0.556834 -0.205147           NaN -0.596182 -0.663715
# ...

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# 'RdBu_r', 'BrBG_r', & PuOr_r are other good diverging colormaps
# Out:
# C:\Users\vivek\miniconda3\envs\tensorflow\lib\site-packages\pandas\io\formats\style.py:3554: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# C:\Users\vivek\miniconda3\envs\tensorflow\lib\site-packages\pandas\io\formats\style.py:3555: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# #T_e1ced_row0_col0, #T_e1ced_row0_col15, #T_e1ced_row1_col1, #T_e1ced_row3_col3, #T_e1ced_row4_col4, #T_e1ced_row5_col5, #T_e1ced_row6_col6, #T_e1ced_row7_col7, #T_e1ced_row7_col9, #T_e1ced_row8_col8, #T_e1ced_row9_col7, #T_e1ced_row9_col9, #T_e1ced_row10_col10, #T_e1ced_row11_col11, #T_e1ced_row12_col12, #T_e1ced_row13_col13, #T_e1ced_row14_col14, #T_e1ced_row15_col0, #T_e1ced_row15_col15, #T_e1ced_row16_col16, #T_e1ced_row17_col17, #T_e1ced_row18_col18 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e1ced_row0_col1, #T_e1ced_row15_col1 {
#   background-color: #e36b54;
# ...

# %%
df.plot(x="Date", y=['pressure'],figsize=(50,50))
plt.show()

# %%
df1.plot()
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
g = sns.pairplot(df1, x_vars="Date", y_vars=df1.columns.values)
g.fig.set_size_inches(30,30)

# %%
import seaborn as sns
g= sns.pairplot(df2, x_vars="Date", y_vars=df2.columns.values)
g.fig.set_size_inches(30,30)
